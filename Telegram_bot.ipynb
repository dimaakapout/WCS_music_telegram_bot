# %%
# ТЕСТИРОВАНИЕ

FIRST_ROW_BPM_CHOICE = ('70-80', '80-90', '90-100', '100-110')
SECOND_ROW_BPM_CHOICE = ('Меньше 80',"80-100", "Больше 100" )

FIRST_ROW_GENRE_CHOICE = ('pop', 'romantic', 'blues')
SECOND_ROW_GENRE_CHOICE = ('Случайно','disco')

TEXT_BPM = FIRST_ROW_BPM_CHOICE + SECOND_ROW_BPM_CHOICE
TEXT_GENRE = FIRST_ROW_GENRE_CHOICE + SECOND_ROW_GENRE_CHOICE

for i in TEXT_BPM:
    for g in TEXT_GENRE:
        print (i, g)
        a = get_track_list(g, get_track_dataframe(i))
        print(a)
# Out:
# 70-80 pop
# []
# 70-80 romantic
# ['https://t.me/wcs_music_sampo/34']
# 70-80 blues
# []
# 70-80 Случайно
# ['https://t.me/wcs_music_sampo/34']
# 70-80 disco
# []
# 80-90 pop
# ['https://t.me/wcs_music_sampo/23' 'https://t.me/wcs_music_sampo/25'
#  'https://t.me/wcs_music_sampo/16' 'https://t.me/wcs_music_sampo/17'
#  'https://t.me/wcs_music_sampo/20' 'https://t.me/wcs_music_sampo/28'
#  'https://t.me/wcs_music_sampo/27' 'https://t.me/wcs_music_sampo/14'
#  'https://t.me/wcs_music_sampo/29' 'https://t.me/wcs_music_sampo/33']
# 80-90 romantic
# ['https://t.me/wcs_music_sampo/31' 'https://t.me/wcs_music_sampo/32'
#  'https://t.me/wcs_music_sampo/15' 'https://t.me/wcs_music_sampo/22'
#  'https://t.me/wcs_music_sampo/13']
# 80-90 blues
# ['https://t.me/wcs_music_sampo/30' 'https://t.me/wcs_music_sampo/24']
# 80-90 Случайно
# ['https://t.me/wcs_music_sampo/32' 'https://t.me/wcs_music_sampo/14'
#  'https://t.me/wcs_music_sampo/22' 'https://t.me/wcs_music_sampo/30'
#  'https://t.me/wcs_music_sampo/26' 'https://t.me/wcs_music_sampo/20'
#  'https://t.me/wcs_music_sampo/17' 'https://t.me/wcs_music_sampo/25'
#  'https://t.me/wcs_music_sampo/15' 'https://t.me/wcs_music_sampo/13']
# 80-90 disco
# ['https://t.me/wcs_music_sampo/32' 'https://t.me/wcs_music_sampo/30'
#  'https://t.me/wcs_music_sampo/29' 'https://t.me/wcs_music_sampo/28']
# 90-100 pop
# ['https://t.me/wcs_music_sampo/49' 'https://t.me/wcs_music_sampo/47'
#  'https://t.me/wcs_music_sampo/71' 'https://t.me/wcs_music_sampo/67'
#  'https://t.me/wcs_music_sampo/70' 'https://t.me/wcs_music_sampo/38'
#  'https://t.me/wcs_music_sampo/65' 'https://t.me/wcs_music_sampo/61'
#  'https://t.me/wcs_music_sampo/55' 'https://t.me/wcs_music_sampo/52']
# 90-100 romantic
# ['https://t.me/wcs_music_sampo/68' 'https://t.me/wcs_music_sampo/43']
# 90-100 blues
# ['https://t.me/wcs_music_sampo/66' 'https://t.me/wcs_music_sampo/58']
# 90-100 Случайно
# ['https://t.me/wcs_music_sampo/48' 'https://t.me/wcs_music_sampo/43'
#  'https://t.me/wcs_music_sampo/47' 'https://t.me/wcs_music_sampo/39'
#  'https://t.me/wcs_music_sampo/18' 'https://t.me/wcs_music_sampo/62'
#  'https://t.me/wcs_music_sampo/51' 'https://t.me/wcs_music_sampo/37'
#  'https://t.me/wcs_music_sampo/58' 'https://t.me/wcs_music_sampo/21']
# 90-100 disco
# ['https://t.me/wcs_music_sampo/47' 'https://t.me/wcs_music_sampo/37'
#  'https://t.me/wcs_music_sampo/61' 'https://t.me/wcs_music_sampo/41'
#  'https://t.me/wcs_music_sampo/18' 'https://t.me/wcs_music_sampo/38'
#  'https://t.me/wcs_music_sampo/43' 'https://t.me/wcs_music_sampo/63'
#  'https://t.me/wcs_music_sampo/54' 'https://t.me/wcs_music_sampo/49']
# 100-110 pop
# ['https://t.me/wcs_music_sampo/12' 'https://t.me/wcs_music_sampo/69'
#  'https://t.me/wcs_music_sampo/10']
# 100-110 romantic
# []
# 100-110 blues
# []
# 100-110 Случайно
# ['https://t.me/wcs_music_sampo/10' 'https://t.me/wcs_music_sampo/69'
#  'https://t.me/wcs_music_sampo/12']
# 100-110 disco
# ['https://t.me/wcs_music_sampo/10']
# Меньше 80 pop
# []
# Меньше 80 romantic
# ['https://t.me/wcs_music_sampo/34']
# Меньше 80 blues
# []
# Меньше 80 Случайно
# ['https://t.me/wcs_music_sampo/34']
# Меньше 80 disco
# []
# 80-100 pop
# ['https://t.me/wcs_music_sampo/60' 'https://t.me/wcs_music_sampo/40'
#  'https://t.me/wcs_music_sampo/56' 'https://t.me/wcs_music_sampo/62'
#  'https://t.me/wcs_music_sampo/21' 'https://t.me/wcs_music_sampo/65'
#  'https://t.me/wcs_music_sampo/70' 'https://t.me/wcs_music_sampo/47'
#  'https://t.me/wcs_music_sampo/27' 'https://t.me/wcs_music_sampo/37']
# 80-100 romantic
# ['https://t.me/wcs_music_sampo/43' 'https://t.me/wcs_music_sampo/15'
#  'https://t.me/wcs_music_sampo/68' 'https://t.me/wcs_music_sampo/32'
#  'https://t.me/wcs_music_sampo/22' 'https://t.me/wcs_music_sampo/31'
#  'https://t.me/wcs_music_sampo/13']
# 80-100 blues
# ['https://t.me/wcs_music_sampo/30' 'https://t.me/wcs_music_sampo/24'
#  'https://t.me/wcs_music_sampo/58' 'https://t.me/wcs_music_sampo/66']
# 80-100 Случайно
# ['https://t.me/wcs_music_sampo/41' 'https://t.me/wcs_music_sampo/47'
#  'https://t.me/wcs_music_sampo/31' 'https://t.me/wcs_music_sampo/70'
#  'https://t.me/wcs_music_sampo/63' 'https://t.me/wcs_music_sampo/46'
#  'https://t.me/wcs_music_sampo/53' 'https://t.me/wcs_music_sampo/66'
#  'https://t.me/wcs_music_sampo/64' 'https://t.me/wcs_music_sampo/68']
# 80-100 disco
# ['https://t.me/wcs_music_sampo/47' 'https://t.me/wcs_music_sampo/49'
#  'https://t.me/wcs_music_sampo/63' 'https://t.me/wcs_music_sampo/64'
#  'https://t.me/wcs_music_sampo/38' 'https://t.me/wcs_music_sampo/54'
#  'https://t.me/wcs_music_sampo/32' 'https://t.me/wcs_music_sampo/28'
#  'https://t.me/wcs_music_sampo/43' 'https://t.me/wcs_music_sampo/18']
# Больше 100 pop
# ['https://t.me/wcs_music_sampo/10' 'https://t.me/wcs_music_sampo/12'
#  'https://t.me/wcs_music_sampo/69' 'https://t.me/wcs_music_sampo/11']
# Больше 100 romantic
# ['https://t.me/wcs_music_sampo/6']
# Больше 100 blues
# []
# Больше 100 Случайно
# ['https://t.me/wcs_music_sampo/10' 'https://t.me/wcs_music_sampo/12'
#  'https://t.me/wcs_music_sampo/6' 'https://t.me/wcs_music_sampo/69'
#  'https://t.me/wcs_music_sampo/11']
# Больше 100 disco
# ['https://t.me/wcs_music_sampo/6' 'https://t.me/wcs_music_sampo/11'
#  'https://t.me/wcs_music_sampo/10']

# %%
# !pip install pytelegrambotapi
# Out:
# Collecting pytelegrambotapi
#   Downloading pyTelegramBotAPI-3.7.2.tar.gz (73 kB)
# Requirement already satisfied: requests in c:\conda2020\lib\site-packages (from pytelegrambotapi) (2.22.0)
# Requirement already satisfied: six in c:\conda2020\lib\site-packages (from pytelegrambotapi) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\conda2020\lib\site-packages (from requests->pytelegrambotapi) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\conda2020\lib\site-packages (from requests->pytelegrambotapi) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\conda2020\lib\site-packages (from requests->pytelegrambotapi) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\conda2020\lib\site-packages (from requests->pytelegrambotapi) (2.8)
# Building wheels for collected packages: pytelegrambotapi
#   Building wheel for pytelegrambotapi (setup.py): started
#   Building wheel for pytelegrambotapi (setup.py): finished with status 'done'
#   Created wheel for pytelegrambotapi: filename=pyTelegramBotAPI-3.7.2-py3-none-any.whl size=52967 sha256=d5eb9c6b484b0561bcc2f8eeda87452d94e0a7669305671c26a7262279660e74
#   Stored in directory: c:\users\aace~1\appdata\local\pip\cache\wheels\67\f0\ac\03cd60451c76956a0a276630ce8676b6f06d78b0df933e5b4a
# Successfully built pytelegrambotapi
# Installing collected packages: pytelegrambotapi
# Successfully installed pytelegrambotapi-3.7.2

# %%
#!pip install pytelegrambotapi==3.7.2
#!pip install numpy==1.16.2
#!pip install pandas==0.25.1

# %%
import numpy as np
import pandas as pd
import telebot

# %%
playlist = pd.read_excel('database.xlsx')

# %%
def get_track_dataframe(bpm):
    '''
    Возвращает отсортированный по 'bpm' DataFrame.
    
    Args:
        bpm - string, ex."90-100"
    Output:
        pd.DataFrame
    '''
    
    if bpm == '70-80':
        tracks = playlist[playlist['bpm'] == 70]
        
    elif bpm == '80-90':
        tracks = playlist[playlist['bpm'] == 80]
        
    elif bpm == '90-100':
        tracks = playlist[playlist['bpm'] == 90]
        
    elif bpm == '100-110':
        tracks = playlist[playlist['bpm'] == 100]
        
    elif bpm == '110-120':
        tracks = playlist[playlist['bpm'] == 110]
        
    elif bpm == 'Меньше 80':
        tracks = playlist[playlist['bpm'] < 80]
        
    elif bpm == '80-100':
        tracks = playlist[(playlist['bpm'] >= 80) & (playlist['bpm'] < 100)]
    
    elif bpm == 'Больше 100':
        tracks = playlist[playlist['bpm'] >= 100]
         
    else:
        print('ERROR') #РАЗОБРАТЬ СЛУЧАЙ ЕСЛИ ПОЛЬЗОВАТЕЛЬ ВВОДИТ ЧТО ТО ДРУГОЕ
        return False  
    
    return tracks

# %%
def get_track_list(genre, tracks):
    '''
    Возвращает список ссылок на музыклальные композиции.
    По умолчанию - 10 случайных композиций, если их меньше,
    чем 10, вернет сколько есть.
    
    Args:
        genre - string, ex."romantic"
    Output:
        np.ndarray
    '''
    # Lambda-функция учитывает случай, если база не может выдать более 10 треков
    func = lambda n: tracks.sample(10) if n>=10 else tracks.sample(n)
    
    if genre in FIRST_ROW_GENRE_CHOICE:
        tracks = tracks[tracks['genre'] == genre]   
        n = tracks.shape[0]
        tracks = func(n) 
    
        return tracks['link'].values
    
    if genre == 'Случайно':
        
        n = tracks.shape[0]
        tracks = func(n)
        return func(n)['link'].values
    
    if genre == 'disco':
        tracks = tracks[tracks['disco'] == 1]
        n = tracks.shape[0]
        tracks = func(n) 
    
        return tracks['link'].values

# %% [markdown]
# """
# Привет, *Дмитрий*!
# Я умею сортировать музыку WCS
# по скорости (bpm) и жанру.
#
# Следуй моим инструкциям
# и я выдам тебе 10 случайных
# треков из своей коллекции.
#
# Сегодня в моей базе *63 композиции*.
# Удачного сампо!
# """

# %%
start_message = '''
Привет, *{0}* \u270c\ufe0f! 
Этот бот умеет подбирать WCS музыку
*по скорости* и *жанру*. 
Следуй моим инструкциям''' + '''
и удачного сампо \u270c\ufe0f!
'''

help_message = '''
*Подписывайся на канал* 

==>   @WCSmusicSAMPO   <==

*Есть идеи как улучшить бота?!*

Пиши на anondimanon@mail.ru
'''

# %%
TOKEN = '1350015176:AAGS7zZe0nA5eIbai3wTYmniAWbUIqp_CCw'

SALUTATION_ROW = ('/start', '/help')

FIRST_ROW_BPM_CHOICE = ('70-80', '80-90', '90-100', '100-110')
SECOND_ROW_BPM_CHOICE = ('Меньше 80',"80-100", "Больше 100" )

FIRST_ROW_GENRE_CHOICE = ('pop', 'romantic', 'blues')
SECOND_ROW_GENRE_CHOICE = ('Случайно','disco')

TEXT_BPM = FIRST_ROW_BPM_CHOICE + SECOND_ROW_BPM_CHOICE
TEXT_GENRE = FIRST_ROW_GENRE_CHOICE + SECOND_ROW_GENRE_CHOICE


    
keyboardChoiceBpm = telebot.types.ReplyKeyboardMarkup(True)
keyboardChoiceBpm.row(*FIRST_ROW_BPM_CHOICE)
keyboardChoiceBpm.row(*SECOND_ROW_BPM_CHOICE)
keyboardChoiceBpm.row(*SALUTATION_ROW)

keyboardChoiceGenre = telebot.types.ReplyKeyboardMarkup(True)
keyboardChoiceGenre.row(*FIRST_ROW_GENRE_CHOICE)
keyboardChoiceGenre.row(*SECOND_ROW_GENRE_CHOICE)
keyboardChoiceGenre.row(*SALUTATION_ROW) 

itunes = playlist.sample(10)['link'].values #Заглушка
select_bpm = '80-90'

bot = telebot.TeleBot(TOKEN) #не забывать перезапускать для обновления бота


## START
@bot.message_handler(commands=['start'])
def start_message(message):
    bot.send_message(message.chat.id, 'start_message')#, parse_mode='Markdown')
    bot.send_message(message.chat.id, 'Выбери скорость', reply_markup=keyboardChoiceBpm) 

    
## HELP
@bot.message_handler(commands=['help'])  
def help_command(message):

    bot.send_message(message.chat.id, help_message, parse_mode='Markdown', reply_markup=keyboardChoiceBpm)

# MAIN
@bot.message_handler(content_types=['text'])
def get_text_messages(message):
    
    if message.text in TEXT_BPM:
        global select_bpm
        select_bpm = message.text
        bot.send_message(message.chat.id, 'Выбери скорость', reply_markup=keyboardChoiceGenre) 
        
    if message.text in TEXT_GENRE:
        itunes = get_track_list(message.text, get_track_dataframe(select_bpm))
        bot.send_message(message.chat.id, 'лови', reply_markup=keyboardChoiceBpm) 
        for i in itunes:
            bot.send_audio(message.from_user.id, i)
    
    if message.text == 'секретик':
        sticers = bot.get_sticker_set('Hot_Cherry')
        sticer_id = sticers.stickers[1].file_id
        bot.send_sticker(message.chat.id, sticer_id)

# %%
bot.polling(none_stop=True, interval=0)
